# %%
import pandas as pd
import os
import re 
import numpy as np

# %%
dir_path = r"C:\Users\hi\OneDrive\Desktop\AI_Elite_13\txt_reviews\txt_reviews"

files = os.listdir(dir_path)

print(files[:5])
# Out:
# ['review_1.txt', 'review_10.txt', 'review_100.txt', 'review_1000.txt', 'review_10000.txt']

# %%
# %%time

l = []
for file in files:
    file_path = dir_path + '/' + file
    with open(file_path, encoding="utf8") as f:
        file_content = f.read()
    l.append(file_content)
# Out:
# Wall time: 1h 28min 41s

# %%
print(files[:5])
# Out:
# ['review_1.txt', 'review_10.txt', 'review_100.txt', 'review_1000.txt', 'review_10000.txt']

# %%
print(files[:10])
# Out:
# ['review_1.txt', 'review_10.txt', 'review_100.txt', 'review_1000.txt', 'review_10000.txt', 'review_100000.txt', 'review_100001.txt', 'review_100002.txt', 'review_100003.txt', 'review_100004.txt']

# %%
productid = []
for i in range(0, len(l)):
    productid.append(l[i].split('\n')[0])

# %%
productid
# Out:
# ['ProductId: B001E4KFG0',
#  'ProductId: B00171APVA',
#  'ProductId: B0019CW0HE',
#  'ProductId: B006F2NYI2',
#  'ProductId: B000P41A28',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000P41A28',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000P41A28',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
#  'ProductId: B000LQORDE',
# ...

# %%
userid = []
for i in range(0, len(l)):
    userid.append(l[i].split('\n')[1])

# %%
userid
# Out:
# ['UserId: A3SGXH7AUHU8GW',
#  'UserId: A21BT40VZCCYT4',
#  'UserId: A2P6ACFZ8FTNVV',
#  'UserId: A132DJVI37RB4X',
#  'UserId: A82WIMR4RSVLI',
#  'UserId: A19W47CXJJP1MI',
#  'UserId: A13LMI7F7UC2VO',
#  'UserId: A29WRXXYKLFTG',
#  'UserId: A2LKCOIVLZWDG5',
#  'UserId: A1GPN9X27K5WN',
#  'UserId: ALK1W410A1W6L',
#  'UserId: A38LOGKDYZ0ZC6',
#  'UserId: ASVMD19XFJEDB',
#  'UserId: A2VPI1E9QI9ZIY',
#  'UserId: A3P27PI9STEKY6',
#  'UserId: A3K3GNZWUYXRUT',
#  'UserId: A2XHFVD0D4ZCNC',
#  'UserId: AH759XLWMDEHT',
#  'UserId: A2DY9M3BW63YY4',
#  'UserId: A5OAW5T030GIA',
#  'UserId: A3DJ2W6UT4C05K',
#  'UserId: A2Z4CLXXG04G4C',
#  'UserId: A3QORCU330BICE',
#  'UserId: A3PIHY8BD4AF7D',
#  'UserId: A30ARMF3JEKEJY',
#  'UserId: ARJ0PAAKAMSU3',
#  'UserId: AFAWC4ZJ29YV1',
#  'UserId: AVBHO826RZLAW',
#  'UserId: AJ83PVJN1Y5EK',
#  'UserId: A14388CFZ5KADP',
#  'UserId: A1ZA0WS2C2XE1K',
#  'UserId: A39PLV0ZAQ7UAX',
#  'UserId: A3F71UH88UHB06',
#  'UserId: AZV26LP92E6WU',
# ...

# %%
profilename = []
for i in range(0, len(l)):
    profilename.append(l[i].split('\n')[2])

# %%
helpfulnessnumerator = []
for i in range(0, len(l)):
    helpfulnessnumerator.append(l[i].split('\n')[3])

# %%
helpfulnessdenominator = []
for i in range(0, len(l)):
    helpfulnessdenominator.append(l[i].split('\n')[4])

# %%
score = []
for i in range(0, len(l)):
    score.append(l[i].split('\n')[5])

# %%
time = []
for i in range(0, len(l)):
    time.append(l[i].split('\n')[6])

# %%
reviewsummary = []
for i in range(0, len(l)):
    reviewsummary.append(l[i].split('\n')[7])

# %%
reviewtext = []
for i in range(0, len(l)):
    reviewtext.append(l[i].split('\n')[8])

# %%
dictionary = {"ProductId":productid, 
              "UserId" : userid,
             "ProfileName":profilename,
             "HelpfulnessNumerator":helpfulnessnumerator,
             "HelpfulnessDenominator":helpfulnessdenominator,
             "Score":score,
             "Time":time,
             "ReviewSummary":reviewsummary,
             "ReviewText":reviewtext}
df = pd.DataFrame(dictionary)
df.head()
# Out:
#                ProductId                  UserId  \
# 0  ProductId: B001E4KFG0  UserId: A3SGXH7AUHU8GW
# 1  ProductId: B00171APVA  UserId: A21BT40VZCCYT4
# 2  ProductId: B0019CW0HE  UserId: A2P6ACFZ8FTNVV
# 3  ProductId: B006F2NYI2  UserId: A132DJVI37RB4X
# 4  ProductId: B000P41A28   UserId: A82WIMR4RSVLI
#
#                      ProfileName     HelpfulnessNumerator  \
# 0        ProfileName: delmartian  HelpfulnessNumerator: 1
# 1     ProfileName: Carol A. Reed  HelpfulnessNumerator: 0
# 2  ProfileName: Melissa Benjamin  HelpfulnessNumerator: 0
# 3         ProfileName: Scottdrum  HelpfulnessNumerator: 2
# 4        ProfileName: Emrose mom  HelpfulnessNumerator: 0
#
#       HelpfulnessDenominator     Score              Time  \
# 0  HelpfulnessDenominator: 1  Score: 5  Time: 1303862400
# 1  HelpfulnessDenominator: 0  Score: 5  Time: 1351209600
# 2  HelpfulnessDenominator: 1  Score: 1  Time: 1331164800
# 3  HelpfulnessDenominator: 5  Score: 2  Time: 1332374400
# ...

# %%
df["ProductId"] = df["ProductId"].str.replace("ProductId: ","")
df["UserId"] = df["UserId"].str.replace("UserId: ","")
df["ProfileName"] = df["ProfileName"].str.replace("ProfileName: ","")

# %%
df["HelpfulnessNumerator"] = df["HelpfulnessNumerator"].str.replace("HelpfulnessNumerator: ","")
df["HelpfulnessDenominator"] = df["HelpfulnessDenominator"].str.replace("HelpfulnessDenominator: ","")
df["Score"] = df["Score"].str.replace("Score: ","")

# %%
df["Time"] = df["Time"].str.replace("Time: ","")

# %%
df["ReviewSummary"] = df["ReviewSummary"].str.replace("ReviewSummary: ","")

# %%
df["ReviewText"] = df["ReviewText"].str.replace("ReviewText: ","")

# %%
df.head(6)
# Out:
#     ProductId          UserId         ProfileName HelpfulnessNumerator  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW          delmartian                    1
# 1  B00171APVA  A21BT40VZCCYT4       Carol A. Reed                    0
# 2  B0019CW0HE  A2P6ACFZ8FTNVV    Melissa Benjamin                    0
# 3  B006F2NYI2  A132DJVI37RB4X           Scottdrum                    2
# 4  B000P41A28   A82WIMR4RSVLI          Emrose mom                    0
# 5  B000LQORDE  A19W47CXJJP1MI  Amazonian Consumer                    2
#
#   HelpfulnessDenominator Score        Time  \
# 0                      1     5  1303862400
# 1                      0     5  1351209600
# 2                      1     1  1331164800
# 3                      5     2  1332374400
# 4                      1     4  1337472000
# 5                      5     5  1235088000
#
#                                        ReviewSummary  \
# 0                              Good Quality Dog Food
# ...

# %%
df.shape
# Out:
# (568454, 9)

# %%
df.to_csv("amazon_reviews.csv")

# %%
df.isnull().sum()
# Out:
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# ReviewSummary             0
# ReviewText                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568454 non-null  object
#  1   UserId                  568454 non-null  object
#  2   ProfileName             568454 non-null  object
#  3   HelpfulnessNumerator    568454 non-null  object
#  4   HelpfulnessDenominator  568454 non-null  object
#  5   Score                   568454 non-null  object
#  6   Time                    568454 non-null  object
#  7   ReviewSummary           568454 non-null  object
#  8   ReviewText              568454 non-null  object
# dtypes: object(9)
# memory usage: 39.0+ MB

# %%
df[["HelpfulnessNumerator", "HelpfulnessDenominator"]] = df[["HelpfulnessNumerator", "HelpfulnessDenominator"]].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568454 non-null  object
#  1   UserId                  568454 non-null  object
#  2   ProfileName             568454 non-null  object
#  3   HelpfulnessNumerator    568454 non-null  int64
#  4   HelpfulnessDenominator  568454 non-null  int64
#  5   Score                   568454 non-null  object
#  6   Time                    568454 non-null  object
#  7   ReviewSummary           568454 non-null  object
#  8   ReviewText              568454 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 39.0+ MB

# %%
df[["Time", "Score"]] = df[["Time", "Score"]].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568454 non-null  object
#  1   UserId                  568454 non-null  object
#  2   ProfileName             568454 non-null  object
#  3   HelpfulnessNumerator    568454 non-null  int64
#  4   HelpfulnessDenominator  568454 non-null  int64
#  5   Score                   568454 non-null  int64
#  6   Time                    568454 non-null  int64
#  7   ReviewSummary           568454 non-null  object
#  8   ReviewText              568454 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 39.0+ MB

# %%
df["Combine_Review"] = df['ReviewSummary'] +' ' + df['ReviewText']

# %%
df.insert(6, 'Helpfulness', df['HelpfulnessNumerator'] / df['HelpfulnessDenominator'])

# %%
df.head()
# Out:
#     ProductId          UserId       ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW        delmartian                     1
# 1  B00171APVA  A21BT40VZCCYT4     Carol A. Reed                     0
# 2  B0019CW0HE  A2P6ACFZ8FTNVV  Melissa Benjamin                     0
# 3  B006F2NYI2  A132DJVI37RB4X         Scottdrum                     2
# 4  B000P41A28   A82WIMR4RSVLI        Emrose mom                     0
#
#    HelpfulnessDenominator  Score  Helpfulness        Time  \
# 0                       1      5          1.0  1303862400
# 1                       0      5          NaN  1351209600
# 2                       1      1          0.0  1331164800
# 3                       5      2          0.4  1332374400
# 4                       1      4          0.0  1337472000
#
#                 ReviewSummary  \
# 0       Good Quality Dog Food
# 1            Healthy Dog Food
# 2                         Bad
# 3       Not hot, not habanero
# 4  The best weve tried so far
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568454 non-null  object
#  1   UserId                  568454 non-null  object
#  2   ProfileName             568454 non-null  object
#  3   HelpfulnessNumerator    568454 non-null  int64
#  4   HelpfulnessDenominator  568454 non-null  int64
#  5   Score                   568454 non-null  int64
#  6   Helpfulness             298402 non-null  float64
#  7   Time                    568454 non-null  int64
#  8   ReviewSummary           568454 non-null  object
#  9   ReviewText              568454 non-null  object
#  10  Combine_Review          568454 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 47.7+ MB

# %%
df['Helpfulness'] = df['Helpfulness'].fillna(df['Helpfulness'].median())

# %%
df.isnull().sum()
# Out:
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Helpfulness               0
# Time                      0
# ReviewSummary             0
# ReviewText                0
# Combine_Review            0
# dtype: int64

# %%
df.head()
# Out:
#     ProductId          UserId       ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW        delmartian                     1
# 1  B00171APVA  A21BT40VZCCYT4     Carol A. Reed                     0
# 2  B0019CW0HE  A2P6ACFZ8FTNVV  Melissa Benjamin                     0
# 3  B006F2NYI2  A132DJVI37RB4X         Scottdrum                     2
# 4  B000P41A28   A82WIMR4RSVLI        Emrose mom                     0
#
#    HelpfulnessDenominator  Score  Helpfulness        Time  \
# 0                       1      5          1.0  1303862400
# 1                       0      5          1.0  1351209600
# 2                       1      1          0.0  1331164800
# 3                       5      2          0.4  1332374400
# 4                       1      4          0.0  1337472000
#
#                 ReviewSummary  \
# 0       Good Quality Dog Food
# 1            Healthy Dog Food
# 2                         Bad
# 3       Not hot, not habanero
# 4  The best weve tried so far
#
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
from tqdm import tqdm, tqdm_notebook
tqdm.pandas()

# %%
lemmatizer = WordNetLemmatizer()

# %%
df.Helpfulness.value_counts()
# Out:
# 1.000000    453361
# 0.000000     33774
# 0.500000     21623
# 0.666667     10514
# 0.750000      6364
#              ...
# 0.754717         1
# 0.978078         1
# 0.697674         1
# 0.067669         1
# 0.970000         1
# Name: Helpfulness, Length: 951, dtype: int64

# %%
y = df['Score']
X = df[["Combine_Review"]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#                                            Combine_Review
# 421329  Excellent service! Product is just as describe...
# 481426  Really not that good Saw the bunch of 5 star r...
# 10962   Green Mountain Coffee Dark Magic is a great ta...
# 277312  very dry and hard to chew sometimes it feels l...
# 68950   Not for POWERFUL chewers Ordered this item bec...

# %%
X_train.shape
# Out:
# (397917, 1)

# %%
y_train.shape
# Out:
# (397917,)

# %%
def preprocess(raw_text, flag):
    
    sentence = re.sub("[^a-zA-Z]", " ", raw_text)
    
    
    sentence = sentence.lower()

    
    tokens = sentence.split()
    
                   
    clean_tokens = [t for t in tokens if not t in stopwords.words("english")]
    
    # Stemming/Lemmatization
    if(flag == 'lemma'):
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    else:
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

#[stemmer.stem(word) for word in clean_tokens]
#[lemmatizer.lemmatize(word) for word in clean_tokens]

# %%
temp_df = X_train["Combine_Review"].progress_apply(lambda x: preprocess(x, 'lemma'))

temp_df.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 397917/397917 [2:14:32<00:00, 49.29it/s]
#                                                         0   1
# 421329  excellent service product described arrived fa...  20
# 481426  really good saw bunch star review thought give...  51
# 10962   green mountain coffee dark magic great tasting...  19
# 277312  dry hard chew sometimes feel like chewing pape...  12
# 68950   powerful chewer ordered item advertised powerf...  33

# %%
X_train = pd.concat([X_train, temp_df], axis=1)

X_train.head()
# Out:
#                                            Combine_Review  \
# 421329  Excellent service! Product is just as describe...
# 481426  Really not that good Saw the bunch of 5 star r...
# 10962   Green Mountain Coffee Dark Magic is a great ta...
# 277312  very dry and hard to chew sometimes it feels l...
# 68950   Not for POWERFUL chewers Ordered this item bec...
#
#                                                         0   1
# 421329  excellent service product described arrived fa...  20
# 481426  really good saw bunch star review thought give...  51
# 10962   green mountain coffee dark magic great tasting...  19
# 277312  dry hard chew sometimes feel like chewing pape...  12
# 68950   powerful chewer ordered item advertised powerf...  33

# %%
temp_df.columns = ['clean_text_lemma', 'text_length_lemma']

temp_df.head()
# Out:
#                                          clean_text_lemma  text_length_lemma
# 421329  excellent service product described arrived fa...                 20
# 481426  really good saw bunch star review thought give...                 51
# 10962   green mountain coffee dark magic great tasting...                 19
# 277312  dry hard chew sometimes feel like chewing pape...                 12
# 68950   powerful chewer ordered item advertised powerf...                 33

# %%
X_train.columns = ['Combine_Review','clean_text_lemma', 'text_length_lemma']
X_train.head()
# Out:
#                                            Combine_Review  \
# 421329  Excellent service! Product is just as describe...
# 481426  Really not that good Saw the bunch of 5 star r...
# 10962   Green Mountain Coffee Dark Magic is a great ta...
# 277312  very dry and hard to chew sometimes it feels l...
# 68950   Not for POWERFUL chewers Ordered this item bec...
#
#                                          clean_text_lemma  text_length_lemma
# 421329  excellent service product described arrived fa...                 20
# 481426  really good saw bunch star review thought give...                 51
# 10962   green mountain coffee dark magic great tasting...                 19
# 277312  dry hard chew sometimes feel like chewing pape...                 12
# 68950   powerful chewer ordered item advertised powerf...                 33

# %%
X_train.head()
# Out:
#                                            Combine_Review  \
# 421329  Excellent service! Product is just as describe...
# 481426  Really not that good Saw the bunch of 5 star r...
# 10962   Green Mountain Coffee Dark Magic is a great ta...
# 277312  very dry and hard to chew sometimes it feels l...
# 68950   Not for POWERFUL chewers Ordered this item bec...
#
#                                          clean_text_lemma  text_length_lemma
# 421329  excellent service product described arrived fa...                 20
# 481426  really good saw bunch star review thought give...                 51
# 10962   green mountain coffee dark magic great tasting...                 19
# 277312  dry hard chew sometimes feel like chewing pape...                 12
# 68950   powerful chewer ordered item advertised powerf...                 33

# %%
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()

X_train_bow = vocab.fit_transform(X_train['clean_text_lemma'])

# %%
X_train_bow
# Out:
# <397917x92477 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13680057 stored elements in Compressed Sparse Row format>

# %%
from sys import getsizeof

print(type(X_train_bow))
print(getsizeof(X_train_bow), "Bytes")
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# 48 Bytes

# %%
X_test.head()
# Out:
#                                            Combine_Review
# 165256  Navitas Organic Dried Goji Berry Powder This p...
# 231465  Lipton instant tea My husband likes quick and ...
# 427827  Good but I wish it had less sodium The flavor ...
# 433954  Great product at a great price! My order was h...
# 70260   Very good My favorite flavor but these sticks ...

# %%
temp_df1 = X_test['Combine_Review'].progress_apply(lambda x: preprocess(x, 'lemma'))

temp_df1.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 170537/170537 [58:29<00:00, 48.59it/s]
#                                                         0   1
# 165256  navitas organic dried goji berry powder produc...  48
# 231465  lipton instant tea husband like quick easy ice...  23
# 427827  good wish le sodium flavor mix good thickness ...  31
# 433954  great product great price order hassle free pr...  20
# 70260   good favorite flavor stick long usually share ...  12

# %%
temp_df1.columns = ['clean_text_lemma2', 'text_length_lemma2']
temp_df1.head()
# Out:
#                                         clean_text_lemma2  text_length_lemma2
# 165256  navitas organic dried goji berry powder produc...                  48
# 231465  lipton instant tea husband like quick easy ice...                  23
# 427827  good wish le sodium flavor mix good thickness ...                  31
# 433954  great product great price order hassle free pr...                  20
# 70260   good favorite flavor stick long usually share ...                  12

# %%
temp_df1.text_length_lemma2.value_counts()
# Out:
# 16     5260
# 15     4981
# 17     4961
# 19     4898
# 14     4867
#        ...
# 642       1
# 820       1
# 728       1
# 569       1
# 469       1
# Name: text_length_lemma2, Length: 511, dtype: int64

# %%
X_test = pd.concat([X_test, temp_df1], axis=1)

X_test.head()
# Out:
#                                            Combine_Review  \
# 165256  Navitas Organic Dried Goji Berry Powder This p...
# 231465  Lipton instant tea My husband likes quick and ...
# 427827  Good but I wish it had less sodium The flavor ...
# 433954  Great product at a great price! My order was h...
# 70260   Very good My favorite flavor but these sticks ...
#
#                                         clean_text_lemma2  text_length_lemma2
# 165256  navitas organic dried goji berry powder produc...                48.0
# 231465  lipton instant tea husband like quick easy ice...                23.0
# 427827  good wish le sodium flavor mix good thickness ...                31.0
# 433954  great product great price order hassle free pr...                20.0
# 70260   good favorite flavor stick long usually share ...                12.0

# %%
X_test['text_length_lemma2'] = X_test['text_length_lemma2'].astype('float64')

# %%
X_test.head()
# Out:
#                                            Combine_Review  \
# 165256  Navitas Organic Dried Goji Berry Powder This p...
# 231465  Lipton instant tea My husband likes quick and ...
# 427827  Good but I wish it had less sodium The flavor ...
# 433954  Great product at a great price! My order was h...
# 70260   Very good My favorite flavor but these sticks ...
#
#                                         clean_text_lemma2  text_length_lemma2
# 165256  navitas organic dried goji berry powder produc...                48.0
# 231465  lipton instant tea husband like quick easy ice...                23.0
# 427827  good wish le sodium flavor mix good thickness ...                31.0
# 433954  great product great price order hassle free pr...                20.0
# 70260   good favorite flavor stick long usually share ...                12.0

# %%
#X_test.drop(['clean_text_lemma1', 'text_length_lemma1'], axis=1, inplace=True)
#X_test.drop(['clean_text_lemma', 'text_length_lemma'], axis=1, inplace=True)

# %%
X_test.head()
# Out:
#                                            Combine_Review  \
# 165256  Navitas Organic Dried Goji Berry Powder This p...
# 231465  Lipton instant tea My husband likes quick and ...
# 427827  Good but I wish it had less sodium The flavor ...
# 433954  Great product at a great price! My order was h...
# 70260   Very good My favorite flavor but these sticks ...
#
#                                         clean_text_lemma2  text_length_lemma2
# 165256  navitas organic dried goji berry powder produc...                48.0
# 231465  lipton instant tea husband like quick easy ice...                23.0
# 427827  good wish le sodium flavor mix good thickness ...                31.0
# 433954  great product great price order hassle free pr...                20.0
# 70260   good favorite flavor stick long usually share ...                12.0

# %%
X_test_bow = vocab.transform(temp_df1['clean_text_lemma2'])

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_bow, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))
# Out:
# 0.7563930408063939
#               precision    recall  f1-score   support
#
#            1       0.69      0.72      0.71     15764
#            2       0.44      0.29      0.35      8825
#            3       0.49      0.36      0.42     12626
#            4       0.53      0.30      0.38     24082
#            5       0.82      0.95      0.88    109240
#
#     accuracy                           0.76    170537
#    macro avg       0.60      0.52      0.55    170537
# weighted avg       0.73      0.76      0.73    170537
